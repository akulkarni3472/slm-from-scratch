# %% [markdown]
# # Small Langauge Model Expermients

# %% [markdown]
# ## Imports

# %%
# Util
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# Tokenizer

# Model

# %% [markdown]
# ## Tokenizer

# %%
# [TODO]

# %% [markdown]
# ## Model
